# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date
from dateutil.relativedelta import relativedelta

# %%
aapl = yf.Ticker("aapl")
aapl.option_chain().calls
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   AAPL220729C00070000 2022-07-22 19:07:50+00:00    70.0      83.71  83.65
# 1   AAPL220729C00075000 2022-07-22 17:24:37+00:00    75.0      78.95  78.65
# 2   AAPL220729C00080000 2022-07-20 19:51:29+00:00    80.0      73.25  73.50
# 3   AAPL220729C00085000 2022-07-22 16:05:53+00:00    85.0      69.40  68.40
# 4   AAPL220729C00090000 2022-07-22 17:10:48+00:00    90.0      64.30  63.80
# ..                  ...                       ...     ...        ...    ...
# 60  AAPL220729C00215000 2022-07-06 18:49:48+00:00   215.0       0.01   0.00
# 61  AAPL220729C00220000 2022-06-21 15:57:09+00:00   220.0       0.01   0.00
# 62  AAPL220729C00230000 2022-06-28 14:35:27+00:00   230.0       0.01   0.00
# 63  AAPL220729C00240000 2022-07-19 14:18:32+00:00   240.0       0.01   0.00
# 64  AAPL220729C00250000 2022-07-21 19:58:58+00:00   250.0       0.01   0.00
#
# ...

# %%
def option_price(expiry, start, r, strike, ticker ):
    stock_data = yf.download(ticker, date.today().strftime("%Y-%m-%d") - rd.relativedelta(days=30), date.today().strftime("%Y-%m-%d"), adjusted=True)

# %%
stock_data = yf.download("aapl", (date.today() - relativedelta(days=31)).strftime("%Y-%m-%d"), date.today().strftime("%Y-%m-%d"), adjusted=True)
stock_returns = stock_data['Adj Close'].pct_change().dropna()
stock_returns
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2022-06-24    0.024517
# 2022-06-27    0.000000
# 2022-06-28   -0.029790
# 2022-06-29    0.013024
# 2022-06-30   -0.018028
# 2022-07-01    0.016164
# 2022-07-05    0.018930
# 2022-07-06    0.009607
# 2022-07-07    0.023999
# 2022-07-08    0.004715
# 2022-07-11   -0.014758
# 2022-07-12    0.006834
# 2022-07-13   -0.002537
# 2022-07-14    0.020482
# 2022-07-15    0.011450
# 2022-07-18   -0.020643
# 2022-07-19    0.026722
# 2022-07-20    0.013510
# 2022-07-21    0.015094
# 2022-07-22   -0.008111
# Name: Adj Close, dtype: float64
